# %% [markdown]
# # Threat Model Cookbook Session - Part 1
#
# Date: Tuesday 4th June 2019
#
# ### Organisers
#
# Jonathan Marcil
# Tash Norris
#
#
# ## Obj
#
# Objective: Overview of what the OWASP Project is about.
#
# The project is about having a list of treath model examples in the form of code, graphical, textual representation.
#
# ### Resources:
#
# - Github repo - https://github.com/OWASP/threat-model-cookbook
#
# - Jonathan's work - https://linktr.ee/threatmodel
#
# - Slack channel - https://owasp.slack.com/messages/CB4KT9XR8
#
# ### Review of Outcomes
#
# | Outcome (documented on Session page) | Activity | Status |
# | ---------------- |---------|--------|
# |Explanation on the way of working | Overview provided to participants | closed |
# |Leadership of the project defined |Leadership confirmed as Tash Norris and Jonathan Marcil | closed|
# |Naming of the project decided (cookbooks or cookbook?) | Tash renamed repo to cookbook | closed |
# |Restructuration of repository (access rights, folders and files) | see "Structure" session below | In Progress |
# |Twitter access shared via Tweetdeck | See action below (Tash) | open |
# |Registration of the OWASP project started | Need to complete | In Progress |
#
# ### Actions:
#
#  - contact OWASP admin (Harold) how to gain access to Threat Model Cookbook (Jonathan will raise ticket to request access)
#  - need to complete "New Project Request" (Jonathan)
#  - contact people who previously contributed/interacted with repo to the Threat Model Cookbook to inform them that an official project is being started (Tash will do? - Tash mentioned that most are in the Slack Threat Modeling channel)
#  - (DONE) rename slack channel to "cookbook" (Tash)
#  - linking references in linking.md with folders (Jonathan)
#  - review/redir the structure of the repository (Jonathan)
#  - add files from Jonathan's work to the repository (Jonathan commited to end of week)
#  - review licenses (Jonathan, code: apache license, anything else creative commons)
#  - review examples to give feedback* by raising issues (people new to Threat Modeling)
#  - check access to Twitter via Tweetdeck adding Jonathan as a user (Tash needs to check)
#
#  *feedback refers to whether or not it is clear for people who are less experienced on Threat Modelling
#
# ### Proposed repo Structure [DRAFT]
#
#
# Action item structure
#
# top level folders:
#
# by methodology/flavors/types/tools
#
#  - PASTA
#  - STRIDE
#  - LINDDUN
#  - ThreatDragonModels
#  - pytm
#  - Attack trees
#    - plantuml
#  - Microsoft TM tool
#  - Graphical vectors software
#  - Whiteboard
#
#
# alternative index by targets/subjects (linking.md):
#  - JuiceShop
#    - PASTA
#    - whiteboard
#  - Project2
#  - FakeExample
#
# license:
#     Code Apache 2.0 license
#     Anything else Creative Commons
#
#
# disclaimer
#  - those are examples of threats and not complete
#    - Create a PR to contribute!
#  - those are examples of diagrams/templates and not perfect
#    - File issues to get explanations / updates!
#
# minimum quality requirement for a PR
#  - issues used by consumers
#  - must be the creator of the model or have point of contact with approval sent to maintainers
#
#
# #### readme.md file
#
# There should be a top-level readme.md as well as a README.md of every folder, where recommendations and links as a reference as it is not within scope of the Project.
#
#
# ### Things to investigate (no assigned actions)
#
#  - disclaimer on front page? (not aligned with specific methodology but can point people to these)
#  - look at OWASP SAMM pages to help understand how to map things to help people find things
#  - have conversations with end-users to find out how they want to use the threat model cookbooks
#  - How can we create TM for other OWASP projects?
#
#
# ### Tash asked the audience what the participants of the session would like to see in this Project.
#
# - It would be great to have the same TM by different people using different techniques and methodologies
#
# - Kim (an academic researcher) may come across examples/links that may be useful to contribute. To propose such things, a PR can be created or an issue should be raised in the repo for another contributor to have a look. However, its important to note that it may depend on licenses. Although other TMs that have been done which are under creative commons could be forked for a version to be hosted in the repo.
#
# ### Various notes
#
# - The Cookbook will not be prescripting different methodologies for TM's. It will be a collation of TM examples, that use the methodologies above. A disclaimer 'we are not aligned to a specific methodolgy' could be added to the Cookbook.
#
#
# ![image](https://user-images.githubusercontent.com/48519931/58894160-63b7c280-86e9-11e9-8dd3-0501d7d5d7c5.png)
